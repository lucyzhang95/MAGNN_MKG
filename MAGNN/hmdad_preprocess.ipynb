# %%
import biothings_client as bt
import os
import re
import pandas as pd

# %%
path = os.path.join(os.getcwd(),"data", "hmdad")
hmdad_path = os.path.join(path, "hmdad_mid.txt")
mid = []
diseases = []
microbes = []
with open(hmdad_path, "r") as file:
    for idx, line in enumerate(file):
        if idx == 0:
            continue
        cols = line.split("\t")[:2]
        cols_lower = [col.lower().strip() for col in cols]
        cols_clean = [
            re.match(r"(.*)\(", col).group(1).strip() if re.match(r"(.*)\(", col) else col
            for col in cols_lower
        ]
        diseases.append(cols_clean[0])
        microbes.append(cols_clean[1])
        mid.append({cols_clean[0]: cols_clean[1]})

print(f"Number of unique diseases: {len(set(diseases))}")
print(f"Number of unique microbes: {len(set(microbes))}")
print(f"Number of edges: {len(mid)}")
# Out:
# Number of unique diseases: 39
# Number of unique microbes: 292
# Number of edges: 483

# %%
bt_d = bt.get_client("disease")
d_query = bt_d.querymany(set(diseases), scopes="disease_ontology.name", fields=["mondo"])
d_mondo = {}
best_results = {}

for entry in d_query:
    if 'query' in entry:
        query = entry['query']
        if 'notfound' not in entry and '_score' in entry:
            if query not in best_results or entry['_score'] > best_results[query]['_score']:
                best_results[query] = entry
        else:
            d_mondo[query] = None

d_mondo.update({query: result['_id'] for query, result in best_results.items()})
# Out:
# Input sequence provided is already in string format. No operation performed
# 13 input query terms found dup hits:	[('liver cirrhosis', 2), ('inflammatory bowel disease', 10), ('allergy', 10), ('atopic dermatitis',
# 19 input query terms found no hit:	['atopy', "whipple's disease", "ileal crohn's disease", 'kidney stones', 'systemic inflammatory resp

# %%
len(d_mondo)
# Out:
# 39

# %%
d_mondo
# Out:
# {'atopy': None,
#  "whipple's disease": None,
#  "ileal crohn's disease": None,
#  'kidney stones': None,
#  'systemic inflammatory response syndrome': None,
#  'guttate psoriasis': None,
#  'gastric and duodenal ulcer': None,
#  'infectious colitis': None,
#  'recurrent wheeze': None,
#  'atopic sensitisation': None,
#  'copd': None,
#  'rheumatoid arthrits': None,
#  'gastro-oesophageal reflux': None,
#  'constipation irritable bowel syndrome': None,
#  'new-onset untreated rheumatoid arthrits': None,
#  'skin and mucosal infections': None,
#  'allergic sensitization': None,
#  'clostridium difficile infection': None,
#  'diarrhea irritable bowel syndrome': None,
#  'liver cirrhosis': 'MONDO:0005155',
#  'inflammatory bowel disease': 'MONDO:0005265',
#  'allergy': 'MONDO:0000775',
#  'colorectal carcinoma': 'MONDO:0024331',
#  'irritable bowel syndrome': 'MONDO:0005052',
#  'atopic dermatitis': 'MONDO:0004980',
#  'type 2 diabetes': 'MONDO:0005148',
#  'cystic fibrosis': 'MONDO:0009061',
#  "crohn's disease": 'MONDO:0005011',
#  'type 1 diabetes': 'MONDO:0005147',
#  'psoriasis': 'MONDO:0005083',
#  'eczema': 'MONDO:0004712',
#  'necrotizing enterocolitis': 'MONDO:0004639',
#  'allergic asthma': 'MONDO:0004784',
#  'ulcerative colitis': 'MONDO:0005101',
#  'obesity': 'MONDO:0011122',
#  'periodontal': 'MONDO:0002635',
#  'bacterial vaginosis': 'MONDO:0005316',
#  'colon cancer': 'MONDO:0021063',
#  'asthma': 'MONDO:0004979'}

# %%
df_d = pd.DataFrame(list(d_mondo.items()), columns=["disease", "mondo"])
out_f = os.path.join(path, "unmapped_diseases.xlsx")
df_d.to_excel(out_f, index=False)

# %% [markdown]
# ***

# %%
microbes = [microbe for microbe in microbes if re.findall(r"\s", microbe)]
print(f"Number of microbes after removing the genus: {len(set(microbes))}")
# Out:
# Number of microbes after removing the genus: 148

# %%
microbes
# Out:
# ['collinsella aerofaciens',
#  'porphyromonas gingivalis',
#  'helicobacter pylori',
#  'helicobacter pylori',
#  'staphylococcus aureus',
#  'bifidobacterium catenulatum',
#  'clostridium coccoides',
#  'ruminococcus productus',
#  'bacteroides fragilis',
#  'clostridium coccoides',
#  'clostridium leptum',
#  'atopobium vaginae',
#  'gardnerella vaginalis',
#  'lactobacillus  crispatus',
#  'clostridium coccoides',
#  'clostridium leptum',
#  'clostridium difficile',
#  'clostridium difficile',
#  'clostridium difficile',
#  'clostridium difficile',
#  'clostridium difficile',
#  'escherichia coli',
#  'helicobacter pylori',
#  'helicobacter pylori',
#  'clostridium cocleatum',
#  'collinsella aerofaciens',
#  'dietzia maris',
#  'stenotrophomonas maltophilia',
#  'staphylococcus aureus',
#  'stenotrophomonas maltophilia',
#  'streptococcus mitis',
#  'staphylococcus aureus',
#  'bacteroides ovatus',
#  'bacteroides ovatus',
#  'bacteroides uniformis',
#  'bacteroides uniformis',
#  'bacteroides vulgatus',
#  'bacteroides vulgatus',
#  'candidate division tm7',
#  'porphyromonas uenonis',
#  'clostridium coccoides',
#  'propionibacterium acnes',
#  'methanobrevibacter smithii',
#  'clostridium leptum',
#  'faecalibacterium prausnitzii',
#  'enterobacter aerogenes',
#  'enterobacter hormaechei',
#  'klebsiella pneumoniae',
#  'shigella dysenteriae',
#  'bifidobacterium catenulatum',
#  'clostridium coccoides',
#  'bacteroides fragilis',
#  'bacteroides ovatus',
#  'bacteroides sp. cj78',
#  'bacteroides thetaiotaomicron',
#  'bacteroides uniformis',
#  'bacteroides vulgatus',
#  'eubacterium eligens',
#  'eubacterium rectale',
#  'human intestinal firmicute cb47',
#  'human intestinal firmicute co19',
#  'enterococcus faecium',
#  'escherichia coli',
#  'atopobium vaginae',
#  'gardnerella vaginalis',
#  'lactobacillus iners',
#  'faecalibacterium prausnitzii',
#  'oxalobacter formigenes',
#  'tropheryma whipplei',
#  'enterococcus faecalis',
#  'bacteroides vulgatus',
#  'haemophilus parainfluenzae',
#  'fusobacterium nucleatum',
#  'bacterium 08.96.4',
#  'bacterium asf500',
#  'bacterium b4c2-5',
#  'bacterium ba2',
#  'bacterium c15',
#  'bacterium g100viii',
#  'bacterium ic1214',
#  'bacterium ic1258',
#  'bacterium ic1292',
#  'bacterium ic1296',
#  'bacterium ic1311',
#  'bacterium ic1379',
#  'bacterium ic1391',
#  'bacterium mb7-1',
#  'bacterium mpn-isolate group 19',
#  'bacterium mpn-isolate group 22',
#  'bacterium mpn-isolate group 24',
#  'bacterium mpn-isolate group 27',
#  'bacterium mpn-isolate group 5',
#  "bacterium 'new zealand b'",
#  'bacterium str. 31285',
#  'bacterium ye62',
#  'bacterium ye64',
#  'bacteroidaceae bacterium smarlab 3301643',
#  'bovine rumen bacterium jpr13',
#  'burkholderiales bacterium smarlab 3302047',
#  'butyrate-producing bacterium art55/1',
#  'butyrate-producing bacterium l1-810',
#  'butyrate-producing bacterium l1-952',
#  'butyrate-producing bacterium l2-50',
#  'butyrate-producing bacterium m104/1',
#  'butyrate-producing bacterium m21/2',
#  'butyrate-producing bacterium m50/1',
#  'butyrate-producing bacterium p607',
#  'butyrate-producing bacterium ph05yb02',
#  'butyrate-producing bacterium ph07ay02',
#  'butyrate-producing bacterium ph07ay3',
#  'butyrate-producing bacterium ph07ay5',
#  'butyrate-producing bacterium ph07by04',
#  'butyrate-producing bacterium sl6/1/1',
#  'butyrate-producing bacterium sm4/1',
#  'butyrate-producing bacterium sr1/1',
#  'butyrate-producing bacterium sr1/5',
#  'butyrate-producing bacterium ss2/1',
#  'butyrate-producing bacterium ssc/2',
#  'butyrate-producing bacterium t2-132',
#  'clostridia bacterium tsw07ca7',
#  'clostridiaceae bacterium bssv31',
#  'clostridiaceae bacterium lemv63',
#  'clostridiaceae bacterium sh032',
#  'clostridiaceae bacterium sk061',
#  'clostridiales bacterium 80/3',
#  'clostridiales bacterium a2-162',
#  'clostridiales bacterium aht16',
#  'clostridiales bacterium l2-14',
#  'clostridium innocuum',
#  'clostridium ramosum',
#  'clostridium spiroforme',
#  'eubacterium tortuosum',
#  'firmicutes bacterium eg14',
#  'firmicutes str. c29',
#  'gram-negative bacterium cl10-2b-4',
#  'human intestinal firmicute cb47',
#  'human intestinal firmicute co13',
#  'human intestinal firmicute co19',
#  'human intestinal firmicute co2',
#  'human intestinal firmicute co35',
#  'human intestinal firmicute co4',
#  'human intestinal firmicute cs26',
#  'lachnospiraceae bacterium a2',
#  'mastodon intestinal bacterium an-22-6',
#  'oscillospiraceae bacterium nml 061048',
#  'rumen bacterium 8/94-32',
#  'rumen bacterium r-7',
#  'rumen bacterium r-9',
#  'segmented filamentous bacterium',
#  'swine fecal bacterium fpc67',
#  'swine fecal bacterium fpc70',
#  'swine fecal bacterium rf3e-xyl1',
#  'swine fecal bacterium sd-pec1',
#  'swine manure pit bacterium ppc108',
#  'unidentified bacterium zf3',
#  'verrucomicrobia bacterium ms-f-88',
#  'staphylococcus aureus',
#  'staphylococcus epidermidis',
#  'leptotrichia amnionii',
#  'helicobacter pylori',
#  'prevotella copri',
#  'alistipes finegoldii',
#  'alistipes putredinis',
#  'bacteroides eggerthii',
#  'bacteroides finegoldii',
#  'bacteroides sp. d20',
#  'bacteroides uniformis',
#  'bilophila wadsworthia',
#  'eubacterium eligens',
#  'eubacterium hallii',
#  'eubacterium rectale',
#  'faecalibacterium prausnitzii',
#  'haemophilus parainfluenzae',
#  'lactobacillus salivarius',
#  'odoribacter splanchnicus',
#  'parabacteroides distasonis',
#  'parabacteroides merdae',
#  'roseburia hominis',
#  'roseburia intestinalis',
#  'ruminococcus gnavus',
#  'streptococcus anginosus',
#  'streptococcus parasanguinis',
#  'streptococcus salivarius',
#  'streptococcus vestibularis',
#  'veillonella atypica',
#  'veillonella dispar',
#  'veillonella parvula']

# %%
bt_taxon = bt.get_client("taxon")
taxon_query = bt_taxon.querymany(set(microbes), scopes=["scientific_name"], fields=["taxid", "rank"])
# Out:
# 56 input query terms found dup hits:	[('candidate division tm7', 10), ('shigella dysenteriae', 10), ('streptococcus anginosus', 10), ('ba
# 20 input query terms found no hit:	['ruminococcus productus', 'eubacterium rectale', 'leptotrichia amnionii', 'swine manure pit bacteri

# %%
taxon_query
# Out:
# [{'query': 'human intestinal firmicute co4',
#   '_id': '165133',
#   '_score': 37.408928,
#   'rank': 'species',
#   'taxid': 165133},
#  {'query': 'butyrate-producing bacterium ph05yb02',
#   '_id': '340475',
#   '_score': 36.8601,
#   'rank': 'species',
#   'taxid': 340475},
#  {'query': 'bacterium ic1391',
#   '_id': '330059',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 330059},
#  {'query': 'mastodon intestinal bacterium an-22-6',
#   '_id': '51840',
#   '_score': 35.371857,
#   'rank': 'species',
#   'taxid': 51840},
#  {'query': 'candidate division tm7',
#   '_id': '1364860',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1364860},
#  {'query': 'candidate division tm7',
#   '_id': '239137',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 239137},
#  {'query': 'candidate division tm7',
#   '_id': '443342',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 443342},
#  {'query': 'candidate division tm7',
#   '_id': '1409904',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1409904},
#  {'query': 'candidate division tm7',
#   '_id': '1409903',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1409903},
#  {'query': 'candidate division tm7',
#   '_id': '1409908',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1409908},
#  {'query': 'candidate division tm7',
#   '_id': '1387480',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1387480},
#  {'query': 'candidate division tm7',
#   '_id': '1409901',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1409901},
#  {'query': 'candidate division tm7',
#   '_id': '1409902',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1409902},
#  {'query': 'candidate division tm7',
#   '_id': '1409905',
#   '_score': 22.966686,
#   'rank': 'species',
#   'taxid': 1409905},
#  {'query': 'human intestinal firmicute co35',
#   '_id': '165261',
#   '_score': 38.92001,
#   'rank': 'species',
#   'taxid': 165261},
#  {'query': 'shigella dysenteriae',
#   '_id': '622',
#   '_score': 24.005556,
#   'rank': 'species',
#   'taxid': 622},
#  {'query': 'shigella dysenteriae',
#   '_id': '1212563',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 1212563},
#  {'query': 'shigella dysenteriae',
#   '_id': '216598',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 216598},
#  {'query': 'shigella dysenteriae',
#   '_id': '300267',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 300267},
#  {'query': 'shigella dysenteriae',
#   '_id': '754093',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 754093},
#  {'query': 'shigella dysenteriae',
#   '_id': '1353980',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 1353980},
#  {'query': 'shigella dysenteriae',
#   '_id': '1401259',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 1401259},
#  {'query': 'shigella dysenteriae',
#   '_id': '1212565',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 1212565},
#  {'query': 'shigella dysenteriae',
#   '_id': '1401327',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 1401327},
#  {'query': 'shigella dysenteriae',
#   '_id': '358708',
#   '_score': 20.999096,
#   'rank': 'strain',
#   'taxid': 358708},
#  {'query': 'ruminococcus productus', 'notfound': True},
#  {'query': 'eubacterium rectale', 'notfound': True},
#  {'query': 'butyrate-producing bacterium sl6/1/1',
#   '_id': '245015',
#   '_score': 37.68468,
#   'rank': 'species',
#   'taxid': 245015},
#  {'query': 'clostridiales bacterium 80/3',
#   '_id': '500389',
#   '_score': 23.868282,
#   'rank': 'species',
#   'taxid': 500389},
#  {'query': 'streptococcus anginosus',
#   '_id': '1328',
#   '_score': 21.887043,
#   'rank': 'species',
#   'taxid': 1328},
#  {'query': 'streptococcus anginosus',
#   '_id': '1671923',
#   '_score': 21.531437,
#   'rank': 'subspecies',
#   'taxid': 1671923},
#  {'query': 'streptococcus anginosus',
#   '_id': '862970',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 862970},
#  {'query': 'streptococcus anginosus',
#   '_id': '862971',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 862971},
#  {'query': 'streptococcus anginosus',
#   '_id': '858698',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 858698},
#  {'query': 'streptococcus anginosus',
#   '_id': '1161422',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 1161422},
#  {'query': 'streptococcus anginosus',
#   '_id': '1163301',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 1163301},
#  {'query': 'streptococcus anginosus',
#   '_id': '1163302',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 1163302},
#  {'query': 'streptococcus anginosus',
#   '_id': '1403946',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 1403946},
#  {'query': 'streptococcus anginosus',
#   '_id': '706437',
#   '_score': 19.145905,
#   'rank': 'strain',
#   'taxid': 706437},
#  {'query': 'human intestinal firmicute cb47',
#   '_id': '165138',
#   '_score': 38.124493,
#   'rank': 'species',
#   'taxid': 165138},
#  {'query': 'bacterium 08.96.4',
#   '_id': '98253',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 98253},
#  {'query': 'butyrate-producing bacterium sr1/5',
#   '_id': '245020',
#   '_score': 34.73779,
#   'rank': 'species',
#   'taxid': 245020},
#  {'query': 'clostridiaceae bacterium bssv31',
#   '_id': '392834',
#   '_score': 28.68405,
#   'rank': 'species',
#   'taxid': 392834},
#  {'query': 'clostridiaceae bacterium sk061',
#   '_id': '433284',
#   '_score': 28.68405,
#   'rank': 'species',
#   'taxid': 433284},
#  {'query': 'bacteroides fragilis',
#   '_id': '817',
#   '_score': 20.079063,
#   'rank': 'species',
#   'taxid': 817},
#  {'query': 'bacteroides fragilis',
#   '_id': '862962',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 862962},
#  {'query': 'bacteroides fragilis',
#   '_id': '295405',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 295405},
#  {'query': 'bacteroides fragilis',
#   '_id': '457424',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 457424},
#  {'query': 'bacteroides fragilis',
#   '_id': '997882',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 997882},
#  {'query': 'bacteroides fragilis',
#   '_id': '997878',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 997878},
#  {'query': 'bacteroides fragilis',
#   '_id': '997879',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 997879},
#  {'query': 'bacteroides fragilis',
#   '_id': '997880',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 997880},
#  {'query': 'bacteroides fragilis',
#   '_id': '997881',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 997881},
#  {'query': 'bacteroides fragilis',
#   '_id': '997883',
#   '_score': 17.564358,
#   'rank': 'strain',
#   'taxid': 997883},
#  {'query': 'streptococcus salivarius',
#   '_id': '1304',
#   '_score': 21.314838,
#   'rank': 'species',
#   'taxid': 1304},
#  {'query': 'streptococcus salivarius',
#   '_id': '347253',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 347253},
#  {'query': 'streptococcus salivarius',
#   '_id': '1074494',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 1074494},
#  {'query': 'streptococcus salivarius',
#   '_id': '1081659',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 1081659},
#  {'query': 'streptococcus salivarius',
#   '_id': '1048332',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 1048332},
#  {'query': 'streptococcus salivarius',
#   '_id': '1157946',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 1157946},
#  {'query': 'streptococcus salivarius',
#   '_id': '1200793',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 1200793},
#  {'query': 'streptococcus salivarius',
#   '_id': '1255635',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 1255635},
#  {'query': 'streptococcus salivarius',
#   '_id': '596322',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 596322},
#  {'query': 'streptococcus salivarius',
#   '_id': '709531',
#   '_score': 18.645365,
#   'rank': 'strain',
#   'taxid': 709531},
#  {'query': 'leptotrichia amnionii', 'notfound': True},
#  {'query': 'bacterium ic1214',
#   '_id': '330018',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 330018},
#  {'query': 'collinsella aerofaciens',
#   '_id': '74426',
#   '_score': 27.972881,
#   'rank': 'species',
#   'taxid': 74426},
#  {'query': 'collinsella aerofaciens',
#   '_id': '1357391',
#   '_score': 24.469553,
#   'rank': 'strain',
#   'taxid': 1357391},
#  {'query': 'collinsella aerofaciens',
#   '_id': '411903',
#   '_score': 21.746075,
#   'rank': 'strain',
#   'taxid': 411903},
#  {'query': 'faecalibacterium prausnitzii',
#   '_id': '853',
#   '_score': 27.918468,
#   'rank': 'species',
#   'taxid': 853},
#  {'query': 'faecalibacterium prausnitzii',
#   '_id': '411485',
#   '_score': 21.703773,
#   'rank': 'strain',
#   'taxid': 411485},
#  {'query': 'faecalibacterium prausnitzii',
#   '_id': '657322',
#   '_score': 21.703773,
#   'rank': 'strain',
#   'taxid': 657322},
#  {'query': 'faecalibacterium prausnitzii',
#   '_id': '718252',
#   '_score': 21.703773,
#   'rank': 'strain',
#   'taxid': 718252},
#  {'query': 'faecalibacterium prausnitzii',
#   '_id': '748224',
#   '_score': 21.703773,
#   'rank': 'strain',
#   'taxid': 748224},
#  {'query': 'odoribacter splanchnicus',
#   '_id': '28118',
#   '_score': 28.982103,
#   'rank': 'species',
#   'taxid': 28118},
#  {'query': 'odoribacter splanchnicus',
#   '_id': '1263090',
#   '_score': 22.53064,
#   'rank': 'strain',
#   'taxid': 1263090},
#  {'query': 'odoribacter splanchnicus',
#   '_id': '709991',
#   '_score': 22.53064,
#   'rank': 'strain',
#   'taxid': 709991},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '1318',
#   '_score': 22.553793,
#   'rank': 'species',
#   'taxid': 1318},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '1403947',
#   '_score': 19.729153,
#   'rank': 'strain',
#   'taxid': 1403947},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '905067',
#   '_score': 19.729153,
#   'rank': 'strain',
#   'taxid': 905067},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '1035185',
#   '_score': 19.729153,
#   'rank': 'strain',
#   'taxid': 1035185},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '1073372',
#   '_score': 19.729153,
#   'rank': 'strain',
#   'taxid': 1073372},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '1095733',
#   '_score': 19.729153,
#   'rank': 'strain',
#   'taxid': 1095733},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '1114965',
#   '_score': 19.729153,
#   'rank': 'strain',
#   'taxid': 1114965},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '760570',
#   '_score': 17.533283,
#   'rank': 'strain',
#   'taxid': 760570},
#  {'query': 'streptococcus parasanguinis',
#   '_id': '888048',
#   '_score': 17.533283,
#   'rank': 'strain',
#   'taxid': 888048},
#  {'query': 'butyrate-producing bacterium l2-50',
#   '_id': '105844',
#   '_score': 35.80237,
#   'rank': 'species',
#   'taxid': 105844},
#  {'query': 'streptococcus vestibularis',
#   '_id': '1343',
#   '_score': 23.759745,
#   'rank': 'species',
#   'taxid': 1343},
#  {'query': 'streptococcus vestibularis',
#   '_id': '904306',
#   '_score': 20.78407,
#   'rank': 'strain',
#   'taxid': 904306},
#  {'query': 'streptococcus vestibularis',
#   '_id': '889206',
#   '_score': 18.470787,
#   'rank': 'strain',
#   'taxid': 889206},
#  {'query': 'veillonella dispar',
#   '_id': '39778',
#   '_score': 21.523241,
#   'rank': 'species',
#   'taxid': 39778},
#  {'query': 'veillonella dispar',
#   '_id': '1357416',
#   '_score': 18.827667,
#   'rank': 'strain',
#   'taxid': 1357416},
#  {'query': 'veillonella dispar',
#   '_id': '1403949',
#   '_score': 18.827667,
#   'rank': 'strain',
#   'taxid': 1403949},
#  {'query': 'veillonella dispar',
#   '_id': '546273',
#   '_score': 16.732132,
#   'rank': 'strain',
#   'taxid': 546273},
#  {'query': 'swine manure pit bacterium ppc108', 'notfound': True},
#  {'query': 'bacterium ye64',
#   '_id': '254754',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 254754},
#  {'query': 'butyrate-producing bacterium ph07ay5',
#   '_id': '340481',
#   '_score': 36.8601,
#   'rank': 'species',
#   'taxid': 340481},
#  {'query': 'enterobacter hormaechei',
#   '_id': '158836',
#   '_score': 21.798414,
#   'rank': 'species',
#   'taxid': 158836},
#  {'query': 'enterobacter hormaechei',
#   '_id': '301105',
#   '_score': 21.462536,
#   'rank': 'subspecies',
#   'taxid': 301105},
#  {'query': 'enterobacter hormaechei',
#   '_id': '1260282',
#   '_score': 19.068377,
#   'rank': 'strain',
#   'taxid': 1260282},
#  {'query': 'enterobacter hormaechei',
#   '_id': '1259823',
#   '_score': 19.068377,
#   'rank': 'strain',
#   'taxid': 1259823},
#  {'query': 'enterobacter hormaechei',
#   '_id': '888063',
#   '_score': 16.946053,
#   'rank': 'strain',
#   'taxid': 888063},
#  {'query': 'enterobacter hormaechei',
#   '_id': '299766',
#   '_score': 16.946053,
#   'rank': 'subspecies',
#   'taxid': 299766},
#  {'query': 'enterobacter hormaechei',
#   '_id': '301102',
#   '_score': 16.946053,
#   'rank': 'subspecies',
#   'taxid': 301102},
#  {'query': 'enterobacter hormaechei',
#   '_id': '1812934',
#   '_score': 16.946053,
#   'rank': 'subspecies',
#   'taxid': 1812934},
#  {'query': 'enterobacter hormaechei',
#   '_id': '1296536',
#   '_score': 16.946053,
#   'rank': 'subspecies',
#   'taxid': 1296536},
#  {'query': 'enterobacter hormaechei',
#   '_id': '1333849',
#   '_score': 15.248843,
#   'rank': 'strain',
#   'taxid': 1333849},
#  {'query': 'lactobacillus salivarius', 'notfound': True},
#  {'query': 'bacteroides sp. d20',
#   '_id': '585543',
#   '_score': 20.924734,
#   'rank': 'species',
#   'taxid': 585543},
#  {'query': 'bacteroides sp. d20',
#   '_id': '2269115',
#   '_score': 16.733358,
#   'rank': 'species',
#   'taxid': 2269115},
#  {'query': 'lactobacillus iners',
#   '_id': '147802',
#   '_score': 22.179478,
#   'rank': 'species',
#   'taxid': 147802},
#  {'query': 'lactobacillus iners',
#   '_id': '879295',
#   '_score': 17.24229,
#   'rank': 'strain',
#   'taxid': 879295},
#  {'query': 'lactobacillus iners',
#   '_id': '888801',
#   '_score': 17.24229,
#   'rank': 'strain',
#   'taxid': 888801},
#  {'query': 'lactobacillus iners',
#   '_id': '525328',
#   '_score': 17.24229,
#   'rank': 'strain',
#   'taxid': 525328},
#  {'query': 'lactobacillus iners',
#   '_id': '713605',
#   '_score': 17.24229,
#   'rank': 'strain',
#   'taxid': 713605},
#  {'query': 'lactobacillus iners',
#   '_id': '879297',
#   '_score': 15.515411,
#   'rank': 'strain',
#   'taxid': 879297},
#  {'query': 'lactobacillus iners',
#   '_id': '879296',
#   '_score': 15.515411,
#   'rank': 'strain',
#   'taxid': 879296},
#  {'query': 'lactobacillus iners',
#   '_id': '879298',
#   '_score': 15.515411,
#   'rank': 'strain',
#   'taxid': 879298},
#  {'query': 'lactobacillus iners',
#   '_id': '879299',
#   '_score': 15.515411,
#   'rank': 'strain',
#   'taxid': 879299},
#  {'query': 'lactobacillus iners',
#   '_id': '879302',
#   '_score': 15.515411,
#   'rank': 'strain',
#   'taxid': 879302},
#  {'query': 'oxalobacter formigenes',
#   '_id': '847',
#   '_score': 30.267635,
#   'rank': 'species',
#   'taxid': 847},
#  {'query': 'oxalobacter formigenes',
#   '_id': '556269',
#   '_score': 26.476913,
#   'rank': 'strain',
#   'taxid': 556269},
#  {'query': 'oxalobacter formigenes',
#   '_id': '649759',
#   '_score': 23.530012,
#   'rank': 'strain',
#   'taxid': 649759},
#  {'query': 'rumen bacterium r-9',
#   '_id': '353158',
#   '_score': 22.919817,
#   'rank': 'species',
#   'taxid': 353158},
#  {'query': 'atopobium vaginae', 'notfound': True},
#  {'query': 'bacterium mpn-isolate group 22',
#   '_id': '157953',
#   '_score': 29.468628,
#   'rank': 'species',
#   'taxid': 157953},
#  {'query': 'eubacterium tortuosum', 'notfound': True},
#  {'query': 'swine fecal bacterium rf3e-xyl1',
#   '_id': '621345',
#   '_score': 37.067696,
#   'rank': 'species',
#   'taxid': 621345},
#  {'query': 'staphylococcus aureus',
#   '_id': '1280',
#   '_score': 14.331942,
#   'rank': 'species',
#   'taxid': 1280},
#  {'query': 'staphylococcus aureus',
#   '_id': '1156994',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1156994},
#  {'query': 'staphylococcus aureus',
#   '_id': '1303786',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1303786},
#  {'query': 'staphylococcus aureus',
#   '_id': '1283278',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1283278},
#  {'query': 'staphylococcus aureus',
#   '_id': '1169263',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1169263},
#  {'query': 'staphylococcus aureus',
#   '_id': '1169266',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1169266},
#  {'query': 'staphylococcus aureus',
#   '_id': '1169271',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1169271},
#  {'query': 'staphylococcus aureus',
#   '_id': '1169272',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1169272},
#  {'query': 'staphylococcus aureus',
#   '_id': '1233245',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1233245},
#  {'query': 'staphylococcus aureus',
#   '_id': '1403931',
#   '_score': 12.537006,
#   'rank': 'strain',
#   'taxid': 1403931},
#  {'query': 'alistipes finegoldii',
#   '_id': '214856',
#   '_score': 26.97028,
#   'rank': 'species',
#   'taxid': 214856},
#  {'query': 'alistipes finegoldii',
#   '_id': '679935',
#   '_score': 20.966652,
#   'rank': 'strain',
#   'taxid': 679935},
#  {'query': 'alistipes finegoldii',
#   '_id': '1263035',
#   '_score': 20.966652,
#   'rank': 'strain',
#   'taxid': 1263035},
#  {'query': 'swine fecal bacterium sd-pec1',
#   '_id': '621359',
#   '_score': 33.968086,
#   'rank': 'species',
#   'taxid': 621359},
#  {'query': 'bacteroides uniformis',
#   '_id': '820',
#   '_score': 22.160631,
#   'rank': 'species',
#   'taxid': 820},
#  {'query': 'bacteroides uniformis',
#   '_id': '997889',
#   '_score': 19.38523,
#   'rank': 'strain',
#   'taxid': 997889},
#  {'query': 'bacteroides uniformis',
#   '_id': '997890',
#   '_score': 19.38523,
#   'rank': 'strain',
#   'taxid': 997890},
#  {'query': 'bacteroides uniformis',
#   '_id': '1235787',
#   '_score': 19.38523,
#   'rank': 'strain',
#   'taxid': 1235787},
#  {'query': 'bacteroides uniformis',
#   '_id': '411479',
#   '_score': 17.227638,
#   'rank': 'strain',
#   'taxid': 411479},
#  {'query': 'bacteroides uniformis',
#   '_id': '1263055',
#   '_score': 17.227638,
#   'rank': 'strain',
#   'taxid': 1263055},
#  {'query': 'bacteroides uniformis',
#   '_id': '1422843',
#   '_score': 17.227638,
#   'rank': 'strain',
#   'taxid': 1422843},
#  {'query': 'bacteroides uniformis',
#   '_id': '1339348',
#   '_score': 14.090966,
#   'rank': 'strain',
#   'taxid': 1339348},
#  {'query': 'bacteroides uniformis',
#   '_id': '1339349',
#   '_score': 14.090966,
#   'rank': 'strain',
#   'taxid': 1339349},
#  {'query': 'lachnospiraceae bacterium a2',
#   '_id': '397290',
#   '_score': 20.979214,
#   'rank': 'species',
#   'taxid': 397290},
#  {'query': 'butyrate-producing bacterium ph07ay3',
#   '_id': '340480',
#   '_score': 36.8601,
#   'rank': 'species',
#   'taxid': 340480},
#  {'query': 'bacterium ye62',
#   '_id': '254752',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 254752},
#  {'query': 'bilophila wadsworthia',
#   '_id': '35833',
#   '_score': 30.825167,
#   'rank': 'species',
#   'taxid': 35833},
#  {'query': 'bilophila wadsworthia',
#   '_id': '1357383',
#   '_score': 26.964619,
#   'rank': 'strain',
#   'taxid': 1357383},
#  {'query': 'bilophila wadsworthia',
#   '_id': '563192',
#   '_score': 26.964619,
#   'rank': 'strain',
#   'taxid': 563192},
#  {'query': 'bilophila wadsworthia',
#   '_id': '1408428',
#   '_score': 23.963436,
#   'rank': 'strain',
#   'taxid': 1408428},
#  {'query': 'human intestinal firmicute co2',
#   '_id': '165136',
#   '_score': 36.561237,
#   'rank': 'species',
#   'taxid': 165136},
#  {'query': 'oscillospiraceae bacterium nml 061048',
#   '_id': '473773',
#   '_score': 36.524445,
#   'rank': 'species',
#   'taxid': 473773},
#  {'query': 'bacterium ic1292',
#   '_id': '330037',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 330037},
#  {'query': 'butyrate-producing bacterium ph07by04',
#   '_id': '340484',
#   '_score': 36.8601,
#   'rank': 'species',
#   'taxid': 340484},
#  {'query': 'veillonella parvula',
#   '_id': '29466',
#   '_score': 21.7599,
#   'rank': 'species',
#   'taxid': 29466},
#  {'query': 'veillonella parvula',
#   '_id': '1316254',
#   '_score': 19.034685,
#   'rank': 'strain',
#   'taxid': 1316254},
#  {'query': 'veillonella parvula',
#   '_id': '1357417',
#   '_score': 19.034685,
#   'rank': 'strain',
#   'taxid': 1357417},
#  {'query': 'veillonella parvula',
#   '_id': '686660',
#   '_score': 16.916111,
#   'rank': 'strain',
#   'taxid': 686660},
#  {'query': 'veillonella parvula',
#   '_id': '479436',
#   '_score': 16.916111,
#   'rank': 'strain',
#   'taxid': 479436},
#  {'query': 'veillonella parvula',
#   '_id': '768727',
#   '_score': 13.836158,
#   'rank': 'strain',
#   'taxid': 768727},
#  {'query': 'butyrate-producing bacterium sm4/1',
#   '_id': '245012',
#   '_score': 35.12513,
#   'rank': 'species',
#   'taxid': 245012},
#  {'query': 'roseburia intestinalis',
#   '_id': '166486',
#   '_score': 24.713474,
#   'rank': 'species',
#   'taxid': 166486},
#  {'query': 'roseburia intestinalis',
#   '_id': '718255',
#   '_score': 21.618355,
#   'rank': 'strain',
#   'taxid': 718255},
#  {'query': 'roseburia intestinalis',
#   '_id': '536231',
#   '_score': 19.212215,
#   'rank': 'strain',
#   'taxid': 536231},
#  {'query': 'roseburia intestinalis',
#   '_id': '1263104',
#   '_score': 19.212215,
#   'rank': 'strain',
#   'taxid': 1263104},
#  {'query': 'roseburia intestinalis',
#   '_id': '657315',
#   '_score': 19.212215,
#   'rank': 'strain',
#   'taxid': 657315},
#  {'query': 'enterobacter aerogenes', 'notfound': True},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '851',
#   '_score': 25.067528,
#   'rank': 'species',
#   'taxid': 851},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '76856',
#   '_score': 23.87054,
#   'rank': 'subspecies',
#   'taxid': 76856},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '189726',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 189726},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1297579',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1297579},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1357398',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1357398},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1402205',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1402205},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1402206',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1402206},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1402202',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1402202},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1402203',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1402203},
#  {'query': 'fusobacterium nucleatum',
#   '_id': '1402204',
#   '_score': 21.928066,
#   'rank': 'strain',
#   'taxid': 1402204},
#  {'query': 'bacterium mpn-isolate group 27',
#   '_id': '157958',
#   '_score': 29.67935,
#   'rank': 'species',
#   'taxid': 157958},
#  {'query': 'clostridiales bacterium a2-162',
#   '_id': '406424',
#   '_score': 27.897528,
#   'rank': 'species',
#   'taxid': 406424},
#  {'query': 'bacterium ic1258',
#   '_id': '330027',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 330027},
#  {'query': 'veillonella atypica',
#   '_id': '39777',
#   '_score': 25.002403,
#   'rank': 'species',
#   'taxid': 39777},
#  {'query': 'veillonella atypica',
#   '_id': '1357415',
#   '_score': 21.871098,
#   'rank': 'strain',
#   'taxid': 1357415},
#  {'query': 'veillonella atypica',
#   '_id': '575616',
#   '_score': 21.871098,
#   'rank': 'strain',
#   'taxid': 575616},
#  {'query': 'veillonella atypica',
#   '_id': '1128111',
#   '_score': 21.871098,
#   'rank': 'strain',
#   'taxid': 1128111},
#  {'query': 'veillonella atypica',
#   '_id': '1357414',
#   '_score': 21.871098,
#   'rank': 'strain',
#   'taxid': 1357414},
#  {'query': 'veillonella atypica',
#   '_id': '866776',
#   '_score': 15.897923,
#   'rank': 'strain',
#   'taxid': 866776},
#  {'query': 'veillonella atypica',
#   '_id': '866778',
#   '_score': 15.897923,
#   'rank': 'strain',
#   'taxid': 866778},
#  {'query': 'bacteroides vulgatus', 'notfound': True},
#  {'query': 'butyrate-producing bacterium sr1/1',
#   '_id': '245019',
#   '_score': 33.38715,
#   'rank': 'species',
#   'taxid': 245019},
#  {'query': 'clostridium coccoides', 'notfound': True},
#  {'query': 'clostridium difficile',
#   '_id': '1780071',
#   '_score': 13.329685,
#   'rank': 'species',
#   'taxid': 1780071},
#  {'query': 'clostridium difficile',
#   '_id': '1780072',
#   '_score': 13.329685,
#   'rank': 'species',
#   'taxid': 1780072},
#  {'query': 'clostridium difficile',
#   '_id': '1780074',
#   '_score': 13.329685,
#   'rank': 'species',
#   'taxid': 1780074},
#  {'query': 'clostridium difficile',
#   '_id': '1780075',
#   '_score': 13.329685,
#   'rank': 'species',
#   'taxid': 1780075},
#  {'query': 'clostridium difficile',
#   '_id': '1780073',
#   '_score': 13.329685,
#   'rank': 'species',
#   'taxid': 1780073},
#  {'query': 'streptococcus mitis',
#   '_id': '28037',
#   '_score': 19.805101,
#   'rank': 'species',
#   'taxid': 28037},
#  {'query': 'streptococcus mitis',
#   '_id': '1008453',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1008453},
#  {'query': 'streptococcus mitis',
#   '_id': '1008452',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1008452},
#  {'query': 'streptococcus mitis',
#   '_id': '1035187',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1035187},
#  {'query': 'streptococcus mitis',
#   '_id': '365659',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 365659},
#  {'query': 'streptococcus mitis',
#   '_id': '1410005',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1410005},
#  {'query': 'streptococcus mitis',
#   '_id': '585204',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 585204},
#  {'query': 'streptococcus mitis',
#   '_id': '1095736',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1095736},
#  {'query': 'streptococcus mitis',
#   '_id': '1410008',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1410008},
#  {'query': 'streptococcus mitis',
#   '_id': '1095735',
#   '_score': 17.324707,
#   'rank': 'strain',
#   'taxid': 1095735},
#  {'query': 'human intestinal firmicute co13',
#   '_id': '165132',
#   '_score': 38.440403,
#   'rank': 'species',
#   'taxid': 165132},
#  {'query': 'butyrate-producing bacterium p607',
#   '_id': '340471',
#   '_score': 36.064583,
#   'rank': 'species',
#   'taxid': 340471},
#  {'query': 'bacterium mb7-1',
#   '_id': '379539',
#   '_score': 20.59919,
#   'rank': 'species',
#   'taxid': 379539},
#  {'query': 'gram-negative bacterium cl10-2b-4',
#   '_id': '245288',
#   '_score': 37.186382,
#   'rank': 'species',
#   'taxid': 245288},
#  {'query': 'verrucomicrobia bacterium ms-f-88',
#   '_id': '579343',
#   '_score': 29.152262,
#   'rank': 'species',
#   'taxid': 579343},
#  {'query': 'clostridium spiroforme', 'notfound': True},
#  {'query': 'bacterium ic1311',
#   '_id': '330043',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 330043},
#  {'query': 'firmicutes str. c29',
#   '_id': '180824',
#   '_score': 26.493212,
#   'rank': 'species',
#   'taxid': 180824},
#  {'query': 'rumen bacterium r-7',
#   '_id': '353157',
#   '_score': 22.618507,
#   'rank': 'species',
#   'taxid': 353157},
#  {'query': 'bacterium str. 31285',
#   '_id': '115998',
#   '_score': 25.158152,
#   'rank': 'species',
#   'taxid': 115998},
#  {'query': 'clostridiaceae bacterium sh032',
#   '_id': '498621',
#   '_score': 28.68405,
#   'rank': 'species',
#   'taxid': 498621},
#  {'query': 'parabacteroides distasonis',
#   '_id': '823',
#   '_score': 26.745865,
#   'rank': 'species',
#   'taxid': 823},
#  {'query': 'parabacteroides distasonis',
#   '_id': '999416',
#   '_score': 23.396208,
#   'rank': 'strain',
#   'taxid': 999416},
#  {'query': 'parabacteroides distasonis',
#   '_id': '999417',
#   '_score': 23.396208,
#   'rank': 'strain',
#   'taxid': 999417},
#  {'query': 'parabacteroides distasonis',
#   '_id': '435591',
#   '_score': 20.792192,
#   'rank': 'strain',
#   'taxid': 435591},
#  {'query': 'parabacteroides distasonis',
#   '_id': '1339341',
#   '_score': 17.006514,
#   'rank': 'strain',
#   'taxid': 1339341},
#  {'query': 'parabacteroides distasonis',
#   '_id': '1339342',
#   '_score': 17.006514,
#   'rank': 'strain',
#   'taxid': 1339342},
#  {'query': 'parabacteroides distasonis',
#   '_id': '1339343',
#   '_score': 17.006514,
#   'rank': 'strain',
#   'taxid': 1339343},
#  {'query': 'parabacteroides distasonis',
#   '_id': '1339344',
#   '_score': 15.587491,
#   'rank': 'strain',
#   'taxid': 1339344},
#  {'query': 'parabacteroides distasonis',
#   '_id': '1339345',
#   '_score': 15.587491,
#   'rank': 'strain',
#   'taxid': 1339345},
#  {'query': 'burkholderiales bacterium smarlab 3302047',
#   '_id': '269289',
#   '_score': 35.8534,
#   'rank': 'species',
#   'taxid': 269289},
#  {'query': 'bacterium ic1379', 'notfound': True},
#  {'query': 'alistipes putredinis',
#   '_id': '28117',
#   '_score': 27.344864,
#   'rank': 'species',
#   'taxid': 28117},
#  {'query': 'alistipes putredinis',
#   '_id': '445970',
#   '_score': 21.25785,
#   'rank': 'strain',
#   'taxid': 445970},
#  {'query': 'alistipes putredinis',
#   '_id': '1263036',
#   '_score': 21.25785,
#   'rank': 'strain',
#   'taxid': 1263036},
#  {'query': 'bacterium ba2',
#   '_id': '299078',
#   '_score': 17.712252,
#   'rank': 'species',
#   'taxid': 299078},
#  {'query': 'bacterium ba2',
#   '_id': '102927',
#   '_score': 15.493966,
#   'rank': 'species',
#   'taxid': 102927},
#  {'query': 'bacterium ba2',
#   '_id': '1637563',
#   '_score': 15.493966,
#   'rank': 'species',
#   'taxid': 1637563},
#  {'query': 'prevotella copri', 'notfound': True},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '2173',
#   '_score': 22.615974,
#   'rank': 'species',
#   'taxid': 2173},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911116',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911116},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911117',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911117},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911118',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911118},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911119',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911119},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911120',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911120},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911121',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911121},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911122',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911122},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911123',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911123},
#  {'query': 'methanobrevibacter smithii',
#   '_id': '911124',
#   '_score': 19.783546,
#   'rank': 'strain',
#   'taxid': 911124},
#  {'query': 'bifidobacterium catenulatum',
#   '_id': '1686',
#   '_score': 24.636135,
#   'rank': 'species',
#   'taxid': 1686},
#  {'query': 'bifidobacterium catenulatum',
#   '_id': '2981616',
#   '_score': 23.839073,
#   'rank': 'subspecies',
#   'taxid': 2981616},
#  {'query': 'bifidobacterium catenulatum',
#   '_id': '1447716',
#   '_score': 19.152092,
#   'rank': 'strain',
#   'taxid': 1447716},
#  {'query': 'bifidobacterium catenulatum',
#   '_id': '630129',
#   '_score': 19.152092,
#   'rank': 'subspecies',
#   'taxid': 630129},
#  {'query': 'bifidobacterium catenulatum',
#   '_id': '566552',
#   '_score': 13.252181,
#   'rank': 'strain',
#   'taxid': 566552},
#  {'query': 'bifidobacterium catenulatum',
#   '_id': '1150460',
#   '_score': 13.252181,
#   'rank': 'strain',
#   'taxid': 1150460},
#  {'query': 'bacteroides ovatus',
#   '_id': '28116',
#   '_score': 21.764233,
#   'rank': 'species',
#   'taxid': 28116},
#  {'query': 'bacteroides ovatus',
#   '_id': '997886',
#   '_score': 19.038477,
#   'rank': 'strain',
#   'taxid': 997886},
#  {'query': 'bacteroides ovatus',
#   '_id': '1379690',
#   '_score': 19.038477,
#   'rank': 'strain',
#   'taxid': 1379690},
#  {'query': 'bacteroides ovatus',
#   '_id': '997885',
#   '_score': 19.038477,
#   'rank': 'strain',
#   'taxid': 997885},
#  {'query': 'bacteroides ovatus',
#   '_id': '665954',
#   '_score': 19.038477,
#   'rank': 'strain',
#   'taxid': 665954},
#  {'query': 'bacteroides ovatus',
#   '_id': '411476',
#   '_score': 16.91948,
#   'rank': 'strain',
#   'taxid': 411476},
#  {'query': 'bacteroides ovatus',
#   '_id': '1263050',
#   '_score': 16.91948,
#   'rank': 'strain',
#   'taxid': 1263050},
#  {'query': 'bacteroides ovatus',
#   '_id': '702443',
#   '_score': 15.224933,
#   'rank': 'strain',
#   'taxid': 702443},
#  {'query': 'bacteroides ovatus',
#   '_id': '1339346',
#   '_score': 13.838915,
#   'rank': 'strain',
#   'taxid': 1339346},
#  {'query': 'bacteroides ovatus',
#   '_id': '1339347',
#   '_score': 13.838915,
#   'rank': 'strain',
#   'taxid': 1339347},
#  {'query': 'butyrate-producing bacterium m21/2',
#   '_id': '245005',
#   '_score': 33.66224,
#   'rank': 'species',
#   'taxid': 245005},
#  {'query': 'roseburia hominis',
#   '_id': '301301',
#   '_score': 24.299109,
#   'rank': 'species',
#   'taxid': 301301},
#  {'query': 'roseburia hominis',
#   '_id': '585394',
#   '_score': 18.890087,
#   'rank': 'strain',
#   'taxid': 585394},
#  {'query': 'eubacterium hallii', 'notfound': True},
#  {'query': 'human intestinal firmicute cs26',
#   '_id': '165131',
#   '_score': 38.124493,
#   'rank': 'species',
#   'taxid': 165131},
#  {'query': 'rumen bacterium 8/94-32',
#   '_id': '371800',
#   '_score': 28.365463,
#   'rank': 'species',
#   'taxid': 371800},
#  {'query': 'butyrate-producing bacterium m50/1',
#   '_id': '245006',
#   '_score': 34.302704,
#   'rank': 'species',
#   'taxid': 245006},
#  {'query': 'butyrate-producing bacterium m104/1',
#   '_id': '245009',
#   '_score': 35.662445,
#   'rank': 'species',
#   'taxid': 245009},
#  {'query': 'bacterium g100viii',
#   '_id': '287820',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 287820},
#  {'query': 'swine fecal bacterium fpc70',
#   '_id': '180360',
#   '_score': 30.588367,
#   'rank': 'species',
#   'taxid': 180360},
#  {'query': 'bovine rumen bacterium jpr13',
#   '_id': '415655',
#   '_score': 31.78035,
#   'rank': 'species',
#   'taxid': 415655},
#  {'query': 'bacterium b4c2-5',
#   '_id': '522595',
#   '_score': 22.776888,
#   'rank': 'species',
#   'taxid': 522595},
#  {'query': 'bacterium c15',
#   '_id': '364927',
#   '_score': 16.196333,
#   'rank': 'species',
#   'taxid': 364927},
#  {'query': 'bacterium c15',
#   '_id': '1489146',
#   '_score': 14.167901,
#   'rank': 'species',
#   'taxid': 1489146},
#  {'query': 'bacterium c15',
#   '_id': '265812',
#   '_score': 14.167901,
#   'rank': 'species',
#   'taxid': 265812},
#  {'query': 'bacterium c15',
#   '_id': '1046185',
#   '_score': 14.167901,
#   'rank': 'species',
#   'taxid': 1046185},
#  {'query': 'bacterium c15',
#   '_id': '1703284',
#   '_score': 14.167901,
#   'rank': 'species',
#   'taxid': 1703284},
#  {'query': 'bacterium c15',
#   '_id': '1145417',
#   '_score': 12.591003,
#   'rank': 'species',
#   'taxid': 1145417},
#  {'query': 'bacterium c15',
#   '_id': '1010005',
#   '_score': 11.3299675,
#   'rank': 'species',
#   'taxid': 1010005},
#  {'query': 'bacterium c15',
#   '_id': '1298909',
#   '_score': 11.3299675,
#   'rank': 'species',
#   'taxid': 1298909},
#  {'query': 'bacterium c15',
#   '_id': '2161979',
#   '_score': 11.3299675,
#   'rank': 'species',
#   'taxid': 2161979},
#  {'query': 'bacterium c15',
#   '_id': '150749',
#   '_score': 10.2985325,
#   'rank': 'species',
#   'taxid': 150749},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '47770',
#   '_score': 21.990383,
#   'rank': 'species',
#   'taxid': 47770},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858651',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858651},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858649',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858649},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858656',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858656},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858659',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858659},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858650',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858650},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858653',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858653},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858655',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858655},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858657',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858657},
#  {'query': 'lactobacillus  crispatus',
#   '_id': '858697',
#   '_score': 19.236303,
#   'rank': 'strain',
#   'taxid': 858697},
#  {'query': 'butyrate-producing bacterium ph07ay02',
#   '_id': '340478',
#   '_score': 36.8601,
#   'rank': 'species',
#   'taxid': 340478},
#  {'query': 'haemophilus parainfluenzae',
#   '_id': '729',
#   '_score': 26.691422,
#   'rank': 'species',
#   'taxid': 729},
#  {'query': 'haemophilus parainfluenzae',
#   '_id': '862965',
#   '_score': 23.348583,
#   'rank': 'strain',
#   'taxid': 862965},
#  {'query': 'haemophilus parainfluenzae',
#   '_id': '1095746',
#   '_score': 23.348583,
#   'rank': 'strain',
#   'taxid': 1095746},
#  {'query': 'haemophilus parainfluenzae',
#   '_id': '1095745',
#   '_score': 23.348583,
#   'rank': 'strain',
#   'taxid': 1095745},
#  {'query': 'haemophilus parainfluenzae',
#   '_id': '888828',
#   '_score': 20.749866,
#   'rank': 'strain',
#   'taxid': 888828},
#  {'query': 'butyrate-producing bacterium ss2/1', 'notfound': True},
#  {'query': 'clostridium innocuum',
#   '_id': '1522',
#   '_score': 23.404388,
#   'rank': 'species',
#   'taxid': 1522},
#  {'query': 'clostridium innocuum',
#   '_id': '450752',
#   '_score': 20.473219,
#   'rank': 'strain',
#   'taxid': 450752},
#  {'query': 'clostridium innocuum',
#   '_id': '665134',
#   '_score': 20.473219,
#   'rank': 'strain',
#   'taxid': 665134},
#  {'query': 'clostridium innocuum',
#   '_id': '999413',
#   '_score': 20.473219,
#   'rank': 'strain',
#   'taxid': 999413},
#  {'query': 'clostridium innocuum',
#   '_id': '1357388',
#   '_score': 20.473219,
#   'rank': 'strain',
#   'taxid': 1357388},
#  {'query': 'clostridium innocuum',
#   '_id': '69832',
#   '_score': 18.194534,
#   'rank': 'species',
#   'taxid': 69832},
#  {'query': 'enterococcus faecium',
#   '_id': '1352',
#   '_score': 18.578289,
#   'rank': 'species',
#   'taxid': 1352},
#  {'query': 'enterococcus faecium',
#   '_id': '1138917',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1138917},
#  {'query': 'enterococcus faecium',
#   '_id': '1138919',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1138919},
#  {'query': 'enterococcus faecium',
#   '_id': '1138921',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1138921},
#  {'query': 'enterococcus faecium',
#   '_id': '1155766',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1155766},
#  {'query': 'enterococcus faecium',
#   '_id': '1344042',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1344042},
#  {'query': 'enterococcus faecium',
#   '_id': '1303770',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1303770},
#  {'query': 'enterococcus faecium',
#   '_id': '1357990',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1357990},
#  {'query': 'enterococcus faecium',
#   '_id': '1328869',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1328869},
#  {'query': 'enterococcus faecium',
#   '_id': '1400824',
#   '_score': 16.25154,
#   'rank': 'strain',
#   'taxid': 1400824},
#  {'query': 'clostridiales bacterium aht16',
#   '_id': '622666',
#   '_score': 27.612114,
#   'rank': 'species',
#   'taxid': 622666},
#  {'query': 'bacterium mpn-isolate group 19',
#   '_id': '157950',
#   '_score': 29.331758,
#   'rank': 'species',
#   'taxid': 157950},
#  {'query': 'escherichia coli',
#   '_id': '562',
#   '_score': 15.0353155,
#   'rank': 'species',
#   'taxid': 562},
#  {'query': 'escherichia coli',
#   '_id': '1125634',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1125634},
#  {'query': 'escherichia coli',
#   '_id': '1125636',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1125636},
#  {'query': 'escherichia coli',
#   '_id': '1125648',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1125648},
#  {'query': 'escherichia coli',
#   '_id': '1147163',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1147163},
#  {'query': 'escherichia coli',
#   '_id': '1147170',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1147170},
#  {'query': 'escherichia coli',
#   '_id': '1147204',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1147204},
#  {'query': 'escherichia coli',
#   '_id': '1147213',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1147213},
#  {'query': 'escherichia coli',
#   '_id': '1147216',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1147216},
#  {'query': 'escherichia coli',
#   '_id': '1147219',
#   '_score': 13.15229,
#   'rank': 'strain',
#   'taxid': 1147219},
#  {'query': 'firmicutes bacterium eg14',
#   '_id': '390750',
#   '_score': 26.072403,
#   'rank': 'species',
#   'taxid': 390750},
#  {'query': 'clostridium leptum',
#   '_id': '1535',
#   '_score': 23.555553,
#   'rank': 'species',
#   'taxid': 1535},
#  {'query': 'clostridium leptum',
#   '_id': '1357389',
#   '_score': 20.60545,
#   'rank': 'strain',
#   'taxid': 1357389},
#  {'query': 'clostridium leptum',
#   '_id': '1263068',
#   '_score': 18.31205,
#   'rank': 'strain',
#   'taxid': 1263068},
#  {'query': 'clostridium leptum',
#   '_id': '428125',
#   '_score': 18.31205,
#   'rank': 'strain',
#   'taxid': 428125},
#  {'query': 'propionibacterium acnes', 'notfound': True},
#  {'query': 'clostridia bacterium tsw07ca7',
#   '_id': '582350',
#   '_score': 29.181137,
#   'rank': 'species',
#   'taxid': 582350},
#  {'query': 'butyrate-producing bacterium ssc/2', 'notfound': True},
#  {'query': 'clostridium ramosum', 'notfound': True},
#  {'query': 'gardnerella vaginalis',
#   '_id': '2702',
#   '_score': 24.765652,
#   'rank': 'species',
#   'taxid': 2702},
#  {'query': 'gardnerella vaginalis',
#   '_id': '682147',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 682147},
#  {'query': 'gardnerella vaginalis',
#   '_id': '858699',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 858699},
#  {'query': 'gardnerella vaginalis',
#   '_id': '907262',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 907262},
#  {'query': 'gardnerella vaginalis',
#   '_id': '1009464',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 1009464},
#  {'query': 'gardnerella vaginalis',
#   '_id': '698950',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 698950},
#  {'query': 'gardnerella vaginalis',
#   '_id': '698951',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 698951},
#  {'query': 'gardnerella vaginalis',
#   '_id': '698961',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 698961},
#  {'query': 'gardnerella vaginalis',
#   '_id': '698955',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 698955},
#  {'query': 'gardnerella vaginalis',
#   '_id': '698957',
#   '_score': 21.663998,
#   'rank': 'strain',
#   'taxid': 698957},
#  {'query': 'clostridiaceae bacterium lemv63',
#   '_id': '179974',
#   '_score': 28.68405,
#   'rank': 'species',
#   'taxid': 179974},
#  {'query': 'bacteroides eggerthii',
#   '_id': '28111',
#   '_score': 25.466486,
#   'rank': 'species',
#   'taxid': 28111},
#  {'query': 'bacteroides eggerthii',
#   '_id': '665953',
#   '_score': 22.277058,
#   'rank': 'strain',
#   'taxid': 665953},
#  {'query': 'bacteroides eggerthii',
#   '_id': '1263043',
#   '_score': 19.797606,
#   'rank': 'strain',
#   'taxid': 1263043},
#  {'query': 'bacteroides eggerthii',
#   '_id': '483216',
#   '_score': 19.797606,
#   'rank': 'strain',
#   'taxid': 483216},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '573',
#   '_score': 17.473392,
#   'rank': 'species',
#   'taxid': 573},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '72407',
#   '_score': 16.642616,
#   'rank': 'subspecies',
#   'taxid': 72407},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1294269',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1294269},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1304918',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1304918},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1304921',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1304921},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1304922',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1304922},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1304923',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1304923},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1304924',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1304924},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1380908',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1380908},
#  {'query': 'klebsiella pneumoniae',
#   '_id': '1455602',
#   '_score': 15.285022,
#   'rank': 'strain',
#   'taxid': 1455602},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '837',
#   '_score': 25.019651,
#   'rank': 'species',
#   'taxid': 837},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1227269',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1227269},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '242619',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 242619},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1321821',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1321821},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1030843',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1030843},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1297564',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1297564},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1297565',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1297565},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1297566',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1297566},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1297567',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1297567},
#  {'query': 'porphyromonas gingivalis',
#   '_id': '1403337',
#   '_score': 21.886185,
#   'rank': 'strain',
#   'taxid': 1403337},
#  {'query': 'bacterium asf500',
#   '_id': '97136',
#   '_score': 20.693048,
#   'rank': 'species',
#   'taxid': 97136},
#  {'query': 'bacterium asf500',
#   '_id': '1378168',
#   '_score': 18.101448,
#   'rank': 'species',
#   'taxid': 1378168},
#  {'query': 'bacteroidaceae bacterium smarlab 3301643',
#   '_id': '269288',
#   '_score': 37.126846,
#   'rank': 'species',
#   'taxid': 269288},
#  {'query': 'helicobacter pylori',
#   '_id': '210',
#   '_score': 20.062994,
#   'rank': 'species',
#   'taxid': 210},
#  {'query': 'helicobacter pylori',
#   '_id': '992018',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 992018},
#  {'query': 'helicobacter pylori',
#   '_id': '1337391',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 1337391},
#  {'query': 'helicobacter pylori',
#   '_id': '1337394',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 1337394},
#  {'query': 'helicobacter pylori',
#   '_id': '1191279',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 1191279},
#  {'query': 'helicobacter pylori',
#   '_id': '1225482',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 1225482},
#  {'query': 'helicobacter pylori',
#   '_id': '1407463',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 1407463},
#  {'query': 'helicobacter pylori',
#   '_id': '866344',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 866344},
#  {'query': 'helicobacter pylori',
#   '_id': '869727',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 869727},
#  {'query': 'helicobacter pylori',
#   '_id': '907237',
#   '_score': 17.5503,
#   'rank': 'strain',
#   'taxid': 907237},
#  {'query': 'bacteroides finegoldii',
#   '_id': '338188',
#   '_score': 24.849548,
#   'rank': 'species',
#   'taxid': 338188},
#  {'query': 'bacteroides finegoldii',
#   '_id': '997888',
#   '_score': 21.737385,
#   'rank': 'strain',
#   'taxid': 997888},
#  {'query': 'bacteroides finegoldii',
#   '_id': '1263045',
#   '_score': 19.317999,
#   'rank': 'strain',
#   'taxid': 1263045},
#  {'query': 'bacteroides finegoldii',
#   '_id': '483215',
#   '_score': 19.317999,
#   'rank': 'strain',
#   'taxid': 483215},
#  {'query': 'bacterium ic1296',
#   '_id': '330039',
#   '_score': 21.309988,
#   'rank': 'species',
#   'taxid': 330039},
#  {'query': 'butyrate-producing bacterium l1-952',
#   '_id': '105833',
#   '_score': 38.645695,
#   'rank': 'species',
#   'taxid': 105833},
#  {'query': 'eubacterium eligens',
#   '_id': '1263077',
#   '_score': 19.43932,
#   'rank': 'strain',
#   'taxid': 1263077},
#  {'query': 'eubacterium eligens',
#   '_id': '515620',
#   '_score': 19.43932,
#   'rank': 'strain',
#   'taxid': 515620},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '40324',
#   '_score': 21.109787,
#   'rank': 'species',
#   'taxid': 40324},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1288955',
#   '_score': 18.465992,
#   'rank': 'isolate',
#   'taxid': 1288955},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1288958',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1288958},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1288959',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1288959},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1212488',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1212488},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1407502',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1407502},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1288956',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1288956},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1288960',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1288960},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '1190567',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 1190567},
#  {'query': 'stenotrophomonas maltophilia',
#   '_id': '868597',
#   '_score': 18.465992,
#   'rank': 'strain',
#   'taxid': 868597},
#  {'query': "bacterium 'new zealand b'",
#   '_id': '292506',
#   '_score': 22.94776,
#   'rank': 'species',
#   'taxid': 292506},
#  {'query': 'butyrate-producing bacterium l1-810',
#   '_id': '105835',
#   '_score': 38.11606,
#   'rank': 'species',
#   'taxid': 105835},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '1282',
#   '_score': 18.7802,
#   'rank': 'species',
#   'taxid': 1282},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '585507',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 585507},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '585508',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 585508},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904322',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904322},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904325',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904325},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904330',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904330},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904332',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904332},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904336',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904336},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904337',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904337},
#  {'query': 'staphylococcus epidermidis',
#   '_id': '904340',
#   '_score': 16.428164,
#   'rank': 'strain',
#   'taxid': 904340},
#  {'query': 'butyrate-producing bacterium art55/1',
#   '_id': '252702',
#   '_score': 36.15904,
#   'rank': 'species',
#   'taxid': 252702},
#  {'query': 'tropheryma whipplei',
#   '_id': '2039',
#   '_score': 27.646751,
#   'rank': 'species',
#   'taxid': 2039},
#  {'query': 'tropheryma whipplei',
#   '_id': '1294027',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1294027},
#  {'query': 'tropheryma whipplei',
#   '_id': '1294034',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1294034},
#  {'query': 'tropheryma whipplei',
#   '_id': '1294038',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1294038},
#  {'query': 'tropheryma whipplei',
#   '_id': '1294039',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1294039},
#  {'query': 'tropheryma whipplei',
#   '_id': '203267',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 203267},
#  {'query': 'tropheryma whipplei',
#   '_id': '218496',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 218496},
#  {'query': 'tropheryma whipplei',
#   '_id': '1293897',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1293897},
#  {'query': 'tropheryma whipplei',
#   '_id': '1294037',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1294037},
#  {'query': 'tropheryma whipplei',
#   '_id': '1294032',
#   '_score': 21.49254,
#   'rank': 'strain',
#   'taxid': 1294032},
#  {'query': 'ruminococcus gnavus', 'notfound': True},
#  {'query': 'clostridiales bacterium l2-14',
#   '_id': '620860',
#   '_score': 25.41811,
#   'rank': 'species',
#   'taxid': 620860},
#  {'query': 'segmented filamentous bacterium',
#   '_id': '33078',
#   '_score': 25.855923,
#   'rank': 'species',
#   'taxid': 33078},
#  {'query': 'segmented filamentous bacterium',
#   '_id': '553310',
#   '_score': 22.978138,
#   'rank': 'species',
#   'taxid': 553310},
#  {'query': 'butyrate-producing bacterium t2-132',
#   '_id': '105837',
#   '_score': 36.725533,
#   'rank': 'species',
#   'taxid': 105837},
#  {'query': 'clostridium cocleatum', 'notfound': True},
#  {'query': 'dietzia maris',
#   '_id': '37915',
#   '_score': 23.602852,
#   'rank': 'species',
#   'taxid': 37915},
#  {'query': 'dietzia maris',
#   '_id': '98514',
#   '_score': 15.008011,
#   'rank': 'species',
#   'taxid': 98514},
#  {'query': 'bacteroides sp. cj78',
#   '_id': '188902',
#   '_score': 24.174206,
#   'rank': 'species',
#   'taxid': 188902},
#  {'query': 'human intestinal firmicute co19',
#   '_id': '165137',
#   '_score': 38.440403,
#   'rank': 'species',
#   'taxid': 165137},
#  {'query': 'unidentified bacterium zf3',
#   '_id': '130789',
#   '_score': 25.357098,
#   'rank': 'species',
#   'taxid': 130789},
#  {'query': 'enterococcus faecalis',
#   '_id': '1351',
#   '_score': 18.388739,
#   'rank': 'species',
#   'taxid': 1351},
#  {'query': 'enterococcus faecalis',
#   '_id': '474186',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 474186},
#  {'query': 'enterococcus faecalis',
#   '_id': '525278',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 525278},
#  {'query': 'enterococcus faecalis',
#   '_id': '1169247',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 1169247},
#  {'query': 'enterococcus faecalis',
#   '_id': '1169292',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 1169292},
#  {'query': 'enterococcus faecalis',
#   '_id': '1400800',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 1400800},
#  {'query': 'enterococcus faecalis',
#   '_id': '1400801',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 1400801},
#  {'query': 'enterococcus faecalis',
#   '_id': '1400802',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 1400802},
#  {'query': 'enterococcus faecalis',
#   '_id': '858687',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 858687},
#  {'query': 'enterococcus faecalis',
#   '_id': '858693',
#   '_score': 16.08573,
#   'rank': 'strain',
#   'taxid': 858693},
#  {'query': 'bacterium mpn-isolate group 5',
#   '_id': '157936',
#   '_score': 28.253267,
#   'rank': 'species',
#   'taxid': 157936},
#  {'query': 'bacterium mpn-isolate group 24',
#   '_id': '157955',
#   '_score': 29.559643,
#   'rank': 'species',
#   'taxid': 157955},
#  {'query': 'swine fecal bacterium fpc67',
#   '_id': '180361',
#   '_score': 30.588367,
#   'rank': 'species',
#   'taxid': 180361},
#  {'query': 'parabacteroides merdae',
#   '_id': '46503',
#   '_score': 26.235168,
#   'rank': 'species',
#   'taxid': 46503},
#  {'query': 'parabacteroides merdae',
#   '_id': '999420',
#   '_score': 22.94947,
#   'rank': 'strain',
#   'taxid': 999420},
#  {'query': 'parabacteroides merdae',
#   '_id': '1357405',
#   '_score': 22.94947,
#   'rank': 'strain',
#   'taxid': 1357405},
#  {'query': 'parabacteroides merdae',
#   '_id': '999421',
#   '_score': 22.94947,
#   'rank': 'strain',
#   'taxid': 999421},
#  {'query': 'parabacteroides merdae',
#   '_id': '1263094',
#   '_score': 20.395176,
#   'rank': 'strain',
#   'taxid': 1263094},
#  {'query': 'parabacteroides merdae',
#   '_id': '411477',
#   '_score': 20.395176,
#   'rank': 'strain',
#   'taxid': 411477},
#  {'query': 'parabacteroides merdae',
#   '_id': '1897013',
#   '_score': 20.395176,
#   'rank': 'species',
#   'taxid': 1897013},
#  {'query': 'porphyromonas uenonis',
#   '_id': '281920',
#   '_score': 27.55243,
#   'rank': 'species',
#   'taxid': 281920},
#  {'query': 'porphyromonas uenonis',
#   '_id': '596327',
#   '_score': 21.419216,
#   'rank': 'strain',
#   'taxid': 596327},
#  {'query': 'porphyromonas uenonis',
#   '_id': '1122976',
#   '_score': 17.519373,
#   'rank': 'strain',
#   'taxid': 1122976},
#  {'query': 'bacteroides thetaiotaomicron',
#   '_id': '818',
#   '_score': 25.022375,
#   'rank': 'species',
#   'taxid': 818},
#  {'query': 'bacteroides thetaiotaomicron',
#   '_id': '1422836',
#   '_score': 21.888569,
#   'rank': 'strain',
#   'taxid': 1422836},
#  {'query': 'bacteroides thetaiotaomicron',
#   '_id': '1235785',
#   '_score': 21.888569,
#   'rank': 'strain',
#   'taxid': 1235785},
#  {'query': 'bacteroides thetaiotaomicron',
#   '_id': '226186',
#   '_score': 19.452354,
#   'rank': 'strain',
#   'taxid': 226186},
#  {'query': 'bacteroides thetaiotaomicron',
#   '_id': '1263054',
#   '_score': 19.452354,
#   'rank': 'strain',
#   'taxid': 1263054},
#  {'query': 'bacteroides thetaiotaomicron',
#   '_id': '1422848',
#   '_score': 19.452354,
#   'rank': 'strain',
#   'taxid': 1422848}]
