# %%
import os
import json

# %%
gmmad2_data_path = os.path.join("json", "gmmad2_data.json")
with open(gmmad2_data_path) as f:
    gmmad2_data = json.load(f)

# %%
faecalis_edge = [(rec["subject"]["name"], rec["object"]["name"]) for rec in gmmad2_data if "taxid" in rec["subject"] if rec["subject"]["taxid"] == 1351]
print(faecalis_edge)
faecalis_edge
# Out:
# [('enterococcus faecalis', 'severe acute malnutrition'), ('enterococcus faecalis', 'autism spectrum disorder'), ('enterococcus faecalis', 'immunoglobulin g4-related disease'), ('enterococcus faecalis', 'covid-19'), ('enterococcus faecalis', 'adenoma'), ('enterococcus faecalis', 'alzheimer disease'), ('enterococcus faecalis', 'anemia, sickle cell'), ('enterococcus faecalis', 'anorexia'), ('enterococcus faecalis', 'arthritis, rheumatoid'), ('enterococcus faecalis', 'attention deficit disorder with hyperactivity'), ('enterococcus faecalis', 'autistic disorder'), ('enterococcus faecalis', 'autoimmune diseases'), ('enterococcus faecalis', 'behcet syndrome'), ('enterococcus faecalis', 'bipolar disorder'), ('enterococcus faecalis', 'breast neoplasms'), ('enterococcus faecalis', 'carcinoma'), ('enterococcus faecalis', 'cardiovascular diseases'), ('enterococcus faecalis', 'celiac disease'), ('enterococcus faecalis', 'clostridium infections'), ('enterococcus faecalis', 'colitis, ulcerative'), 
# ...

# %%
faecium_edge = [(rec["subject"]["name"], rec["object"]["name"]) for rec in gmmad2_data if "taxid" in rec["subject"] if rec["subject"]["taxid"] == 1352]

# %%
print(len(faecium_edge))
faecium_edge
# Out:
# 83
# [('enterococcus faecium', 'severe acute malnutrition'),
#  ('enterococcus faecium', 'autism spectrum disorder'),
#  ('enterococcus faecium', 'immunoglobulin g4-related disease'),
#  ('enterococcus faecium', 'covid-19'),
#  ('enterococcus faecium', 'adenoma'),
#  ('enterococcus faecium', 'alzheimer disease'),
#  ('enterococcus faecium', 'anemia, sickle cell'),
#  ('enterococcus faecium', 'anorexia'),
#  ('enterococcus faecium', 'arthritis, rheumatoid'),
#  ('enterococcus faecium', 'attention deficit disorder with hyperactivity'),
#  ('enterococcus faecium', 'autistic disorder'),
#  ('enterococcus faecium', 'autoimmune diseases'),
#  ('enterococcus faecium', 'behcet syndrome'),
#  ('enterococcus faecium', 'bipolar disorder'),
#  ('enterococcus faecium', 'breast neoplasms'),
#  ('enterococcus faecium', 'carcinoma'),
#  ('enterococcus faecium', 'cardiovascular diseases'),
#  ('enterococcus faecium', 'celiac disease'),
#  ('enterococcus faecium', 'clostridium infections'),
# ...
